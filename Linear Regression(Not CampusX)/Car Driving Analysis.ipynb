# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('car driving risk analysis.csv')
df.head()
# Out:
#    speed  risk
# 0    200    95
# 1     90    20
# 2    300    98
# 3    110    60
# 4    240    72

# %%
plt.scatter(df['speed'],df['risk'])
plt.xlabel('speed')
plt.ylabel('risk')
plt.title('Driving Risk Analysis')
# Out:
# Text(0.5, 1.0, 'Driving Risk Analysis')

# %%
x=df[['speed']]
x.head()
# Out:
#    speed
# 0    200
# 1     90
# 2    300
# 3    110
# 4    240

# %%
y=df[['risk']]
y.head()
# Out:
#    risk
# 0    95
# 1    20
# 2    98
# 3    60
# 4    72

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
m=reg.coef_
m
# Out:
# array([[0.35131645]])

# %%
c=reg.intercept_
c
# Out:
# array([-7.31985478])

# %%
reg.predict([[130]])
# Out:
# C:\Users\rezwa\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[38.35128319]])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
df['predicted_risk']=reg.predict(x)
df.head()
