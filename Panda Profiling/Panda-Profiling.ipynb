# %% [markdown]
# ### Didn't work in here but did it in google collab perfectly

# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Using cached joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\rezwa\appdata\local\programs\python\python313\lib\site-packages (from pandas-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\rezwa\appdata\local\programs\python\python313\lib\site-packages (from pandas-profiling) (2.2.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\rezwa\appdata\local\programs\python\python313\lib\site-packages (from pandas-profiling) (3.10.3)
# Collecting pydantic>=1.8.1 (from pandas-profiling)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\rezwa\appdata\local\programs\python\python313\lib\site-packages (from pandas-profiling) (6.0.2)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\rezwa\appdata\local\programs\python\python313\lib\site-packages (from pandas-profiling) (3.1.6)
# Collecting markupsafe~=2.1.1 (from pandas-profiling)
#   Using cached MarkupSafe-2.1.5.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\rezwa\appdata\local\programs\python\python313\lib\site-packages (from pandas-profiling) (2.2.4)
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [27 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\rezwa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#       main()
#       ~~~~^^
#     File "C:\Users\rezwa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#                                ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\rezwa\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 118, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "C:\Users\rezwa\AppData\Local\Temp\pip-build-env-5_fhvtsu\overlay\Lib\site-packages\setuptools\build_meta.py", line 331, in get_requires_for_build_wheel
#       return self._get_build_requires(config_settings, requirements=[])
#              ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\rezwa\AppData\Local\Temp\pip-build-env-5_fhvtsu\overlay\Lib\site-packages\setuptools\build_meta.py", line 301, in _get_build_requires
#       self.run_setup()
#       ~~~~~~~~~~~~~~^^
#     File "C:\Users\rezwa\AppData\Local\Temp\pip-build-env-5_fhvtsu\overlay\Lib\site-packages\setuptools\build_meta.py", line 512, in run_setup
#       super().run_setup(setup_script=setup_script)
#       ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\rezwa\AppData\Local\Temp\pip-build-env-5_fhvtsu\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#       exec(code, locals())
#       ~~~~^^^^^^^^^^^^^^^^
#     File "<string>", line 4, in <module>
#     File "C:\Users\rezwa\AppData\Local\Temp\pip-install-_zodjwt_\htmlmin_d72ebfaf9363453e9c641abf2de79e45\htmlmin\__init__.py", line 28, in <module>
#       from .main import minify, Minifier
#     File "C:\Users\rezwa\AppData\Local\Temp\pip-install-_zodjwt_\htmlmin_d72ebfaf9363453e9c641abf2de79e45\htmlmin\main.py", line 28, in <module>
#       import cgi
#   ModuleNotFoundError: No module named 'cgi'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: subprocess-exited-with-error
#
# Getting requirements to build wheel did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof = ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# ModuleNotFoundError: No module named 'pandas_profiling'
